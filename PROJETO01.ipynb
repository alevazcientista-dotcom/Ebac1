# %% [markdown]
# <a href="https://colab.research.google.com/github/alevazcientista-dotcom/Ebac1/blob/main/PROJETO01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJETO01**

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# %%
# Observe que demo01.csv está na mesma pasta que este notebook
# do contrário, seria necessário indicar a pasta no nome do arquivo
df = pd.read_csv('/content/demo01 (1).csv')
print ("Número de linhas e colunas da tabela: {}".format(df.shape))

df.head()
# Out:
# Número de linhas e colunas da tabela: (16650, 16)
#   sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0    M                Y               Y           0               Working
# 1    F                N               Y           0  Commercial associate
# 2    F                N               Y           0  Commercial associate
# 3    M                Y               Y           0               Working
# 4    F                Y               N           0               Working
#
#                         educacao          estado_civil    tipo_residencia  \
# 0  Secondary / secondary special               Married  House / apartment
# 1  Secondary / secondary special  Single / not married  House / apartment
# 2  Secondary / secondary special  Single / not married  House / apartment
# 3               Higher education               Married  House / apartment
# 4              Incomplete higher               Married  House / apartment
#
# ...

# %%
# Create a dummy demo01.csv file
data = {'col1': [1, 2, 3], 'col2': ['A', 'B', 'C']}
df_dummy = pd.DataFrame(data)
df_dummy.to_csv('demo01.csv', index=False)

# %%
print(df['mau'].value_counts())
print("\nTaxa de inadimplentes:")
print(df['mau'].mean())
# Out:
# mau
# False    16260
# True       390
# Name: count, dtype: int64
#
# Taxa de inadimplentes:
# 0.023423423423423424

# %%
var = 'mau'
grafico_barras = df[var].value_counts().plot.bar()

# %% [markdown]
# **01 - gráfico de barras**
#
#  Com base no código da célula anterior, construa um gráfico de barras para pelo menos duas outras variáveis.
# **Dica:** Não tente usar as variáveis ```tempo_emprego``` e ```idade``` pois o gráfico de barras dessa forma como construímos não é adequado para elas. </span>

# %%
var = 'estado_civil'
grafico_barras = df[var].value_counts().plot.bar()

# %%
var = 'educacao'
grafico_barras = df[var].value_counts().plot.bar()

# %%
var = 'sexo'
grafico_barras = df[var].value_counts().plot.bar()

# %%
var = 'tipo_renda'
grafico_barras = df[var].value_counts().plot.bar()

# %%
var = 'qtd_filhos'
grafico_barras = df[var].value_counts().plot.bar()

# %% [markdown]
# **02 - Histograma**
#
# <span style="color:blue"> Com base no código da célula anterior, construa o histograma da variavel ```idade```.  </span>

# %%
var = 'idade'
cat_srs, bins = pd.qcut(df[var], 4, retbins=True)
g = df.groupby(cat_srs)
biv = g['mau'].mean()

ax = biv.plot.line()
ax.set_ylabel("Proporção de inadimplentes")
ticks = plt.xticks(range(len(biv.index.values)), biv.index.values, rotation = 90)
# Out:
# /tmp/ipython-input-4160224667.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g = df.groupby(cat_srs)

# %%
var = 'sexo'
# Use groupby to calculate the mean of 'mau' for each sex
biv = df.groupby(var)['mau'].mean()

ax = biv.plot.bar()
ax.set_ylabel("Proporção de inadimplentes")
ticks = plt.xticks(range(len(biv.index.values)), biv.index.values, rotation = 0)

# %%
var = 'educacao'
# Use groupby to calculate the mean of 'mau' for each education level
biv = df.groupby(var)['mau'].mean()

ax = biv.plot.bar()
ax.set_ylabel("Proporção de inadimplentes")
ticks = plt.xticks(range(len(biv.index.values)), biv.index.values, rotation = 90)

# %%
var = 'estado_civil'
# Use groupby to calculate the mean of 'mau' for each civil status
biv = df.groupby(var)['mau'].mean()

ax = biv.plot.bar()
ax.set_ylabel("Proporção de inadimplentes")
ticks = plt.xticks(range(len(biv.index.values)), biv.index.values, rotation = 90)

# %%
var = 'idade'
cat_srs, bins = pd.qcut(df[var], 4, retbins=True)
g = df.groupby(cat_srs)
biv = g['mau'].mean()

ax = biv.plot.line()
ax.set_ylabel("Proporção de inadimplentes")
ticks = plt.xticks(range(len(biv.index.values)), biv.index.values, rotation = 90)
# Out:
# /tmp/ipython-input-4160224667.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g = df.groupby(cat_srs)

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# %%
# Observe que demo01.csv está na mesma pasta que este notebook
df = pd.read_csv('demo01.csv')
print ("Número de linhas e colunas da tabela: {}".format(df.shape))

df.head()
# Out:
# Número de linhas e colunas da tabela: (3, 2)
#    col1 col2
# 0     1    A
# 1     2    B
# 2     3    C
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['col1'].plot(kind='hist', bins=20, title='col1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('col2').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
# Ensure df contains the correct data with the 'mau' column
df = pd.read_csv('/content/demo01 (1).csv')

print(df['mau'].value_counts())
print("\nTaxa de inadimplentes:")
print(df['mau'].mean())
# Out:
# mau
# False    16260
# True       390
# Name: count, dtype: int64
#
# Taxa de inadimplentes:
# 0.023423423423423424

# %% [markdown]
#  **03 - Bivariada**
#
# <span style="color:blue"> Com base no código da célula anterior, construa uma análise bivariada para a variável  ```tempo_emprego```.  Em seguida, insira uma célula de markdown e conclua se a variável parece discriminar risco de crédito. </span>

# %%
import matplotlib.pyplot as plt
col = 'qtd_filhos'
df[col].hist(bins=20)
plt.title('Histograma de ' + col)
plt.xlabel(col)
plt.ylabel('Frequência')
plt.show()

# %%
import matplotlib.pyplot as plt
col = 'tempo_emprego'
df[col].hist(bins=20)
plt.title('Histograma de ' + col)
plt.xlabel(col)
plt.ylabel('Frequência')
plt.show()

# %%
import matplotlib.pyplot as plt
col = 'estado_civil'
df[col].hist(bins=20)
plt.title('Histograma de ' + col)
plt.xlabel(col)
plt.ylabel('Frequência')
plt.show()

# %%
import matplotlib.pyplot as plt

var = 'mau'
grafico_barras = df[var].value_counts().plot.bar()
plt.title('Distribuição de ' + var)
plt.xlabel(var)
plt.ylabel('Frequência')
plt.show()

# %%
print('Colunas do dataset:')
print(list(df.columns))
# Out:
# Colunas do dataset:
# ['sexo', 'posse_de_veiculo', 'posse_de_imovel', 'qtd_filhos', 'tipo_renda', 'educacao', 'estado_civil', 'tipo_residencia', 'idade', 'tempo_emprego', 'possui_celular', 'possui_fone_comercial', 'possui_fone', 'possui_email', 'qt_pessoas_residencia', 'mau']

# %% [markdown]
# *** 4) Análise bivariada: relação entre estado civil e inadimplência ***

# %%
import pandas as pd
col_estado = 'tipo_renda'
col_inad = 'mau'

if col_estado in df.columns and col_inad in df.columns:
    tab = pd.crosstab(df[col_estado], df[col_inad], normalize='index') * 100
    display(tab.round(2))
    ax = tab.plot(kind='bar', stacked=True, figsize=(8,5))
    ax.set_ylabel('Percentual por estado civil (%)')
    ax.set_title('Relação: ' + str(col_estado) + ' x ' + str(col_inad) + ' (percentual por linha)')
    plt.legend(title=col_inad, bbox_to_anchor=(1.0,1.0))
    plt.show()
else:
    print('Coluna(s) necessárias para bivariada não encontradas.')
# Out:
# mau                    False  True
# tipo_renda
# Commercial associate   97.44   2.56
# Pensioner              97.21   2.79
# State servant          98.21   1.79
# Student               100.00   0.00
# Working                97.81   2.19

# %% [markdown]
# **5 - Modelagem — RandomForest**

# %%
# Ensure cell tar7SX0-nMBB (data splitting) is executed before this cell.
# Train a Random Forest model

clf = RandomForestClassifier(n_estimators=3)
# Use X_train and y_train as defined in cell tar7SX0-nMBB
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=3)

# %%
# Assuming the best model from GridSearchCV in tar7SX0-nMBB is named 'best'
# If you only ran the baseline model in tar7SX0-nMBB, you can use 'rf' instead

# Get feature importances
importances = best.feature_importances_

# Get feature names
feature_names = X_train.columns

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'feature': feature_names, 'importance': importances})

# Sort features by importance
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

# Display the top features (you can adjust the number)
print("Feature Importances (from the best RandomForest model):")
display(feature_importance_df.head(10))

# You can also visualize all feature importances
plt.figure(figsize=(10, 6))
plt.bar(feature_importance_df['feature'], feature_importance_df['importance'])
plt.xticks(rotation=90)
plt.ylabel('Importance')
plt.title('Feature Importances from RandomForest')
plt.tight_layout()
plt.show()
# Out:
# Feature Importances (from the best RandomForest model):
#                   feature  importance
# 1                   idade    0.354151
# 2           tempo_emprego    0.258956
# 7   qt_pessoas_residencia    0.046442
# 9      posse_de_veiculo_Y    0.029608
# 0              qtd_filhos    0.029067
# 8                  sexo_M    0.028578
# 10      posse_de_imovel_Y    0.026260
# 5             possui_fone    0.024626
# 14     tipo_renda_Working    0.022031
# 11   tipo_renda_Pensioner    0.021581

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

# %%
# Certifique-se de ter rodado:
# y_pred = clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)

# Supondo que: 0 = Bom pagador, 1 = Mau pagador (inadimplente)
# Matriz no formato:
# [[Verdadeiro Bom, Falso Mau],
#  [Falso Bom, Verdadeiro Mau]]
#
# Ou seja:
# cm[0,0] = bons aprovados
# cm[0,1] = bons reprovados
# cm[1,0] = maus aprovados
# cm[1,1] = maus reprovados

bons_aprovados = cm[0,0]
bons_reprovados = cm[0,1]
maus_aprovados = cm[1,0]
maus_reprovados = cm[1,1]

# %%
# Definir valores financeiros
lucro_bom = 5       # lucro por bom pagador aprovado
prejuizo_mau = -100 # prejuízo por mau pagador aprovado
lucro_aprovar = (bons_aprovados * lucro_bom) + (maus_aprovados * prejuizo_mau)
lucro_reprovar = (bons_reprovados * lucro_bom) + (maus_reprovados * prejuizo_mau)

# %%
import pandas as pd

avaliacao_financeira = pd.DataFrame({
    "Decisão": ["Aprovar", "Reprovar"],
    "Lucro dos bons": [bons_aprovados * lucro_bom, bons_reprovados * lucro_bom],
    "Lucro dos maus": [maus_aprovados * prejuizo_mau, maus_reprovados * prejuizo_mau],
    "Total": [lucro_aprovar, lucro_reprovar]
})

print("\nAvaliação financeira do modelo (baseada na matriz de confusão):\n")
print(avaliacao_financeira.to_string(index=False))

# Impacto financeiro total (lucro geral)
impacto_total = avaliacao_financeira["Total"].sum()

print(f"\nImpacto total estimado do modelo: {impacto_total:.2f} 'dinheiros'")

# Mostrar ganho em relação a uma situação hipotética sem modelo
if lucro_reprovar < 0:
    ganho = abs(lucro_reprovar)
    print(f"O modelo evita um prejuízo estimado de {ganho:.2f} 'dinheiros'.")
# Out:
# Avaliação financeira do modelo (baseada na matriz de confusão):
#
#  Decisão  Lucro dos bons  Lucro dos maus  Total
#  Aprovar           20165           -7200  12965
# Reprovar             160           -2600  -2440
#
# Impacto total estimado do modelo: 10525.00 'dinheiros'
# O modelo evita um prejuízo estimado de 2440.00 'dinheiros'.

# %% [markdown]
# **Treinar uma Random Forest com 5 árvores**

# %%
# Ensure cell tar7SX0-nMBB (data splitting) is executed before this cell.
# Train a Random Forest model with 10 trees

clf = RandomForestClassifier(n_estimators=4)
# Use X_train and y_train as defined in cell tar7SX0-nMBB
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=4)

# %%
# Calculando a acuracia
from sklearn import metrics # Ensure metrics is imported

# Ensure cell tar7SX0-nMBB (data splitting) is executed before this cell to define X_test and y_test.

y_pred = clf.predict(X_test) # Use X_test
acc = metrics.accuracy_score(y_test, y_pred)
print('Acurácia: {0:.2f}%'.format(acc*100))
# Out:
# Acurácia: 97.57%

# %%
# Matriz de confusão

tab = pd.crosstab(index = y_pred, columns = y_test)
print("Confusion Matrix:")
display(tab)

# Calculate rates using boolean labels
# Assuming True is the positive class (inadimplente) and False is the negative class (bom pagador)
# Based on the structure of the original formulas, calculating False Positive Rate and Precision for True class

# False Positive Rate (FPR): FP / (FP + TN)
# In the crosstab with index=y_pred (predicted) and columns=y_test (actual):
# Predicted True, Actual False (FP) is tab[True][False]
# Predicted False, Actual False (TN) is tab[False][False]
false_positive_rate = tab[False][True] / (tab[False][True] + tab[False][False]) if (tab[False][True] + tab[False][False]) != 0 else 0

# Precision (for True class): TP / (TP + FP)
# Predicted True, Actual True (TP) is tab[True][True]
# Predicted True, Actual False (FP) is tab[True][False]
precision_true = tab[True][True] / (tab[True][True] + tab[True][False]) if (tab[True][True] + tab[True][False]) != 0 else 0

print("\nFalse Positive Rate:", false_positive_rate)
print("Precision (for True class):", precision_true)
# Out:
# Confusion Matrix:
# mau    False  True
# row_0
# False   4048     84
# True      17     14
# False Positive Rate: 0.004182041820418204
# Precision (for True class): 0.14285714285714285

# %% [markdown]
# **Conclusões**
#
# - Foram reproduzidos gráficos de barras para as variáveis categóricas solicitadas (estado civil, educaçãp, sexo, qtd filhos, idade, tempo de emprego, status e inadimplente), um histograma para uma variável numérica automática e uma bivariada entre estado civil e inadimplência.
# - A RandomForest foi treinada em divisão treino/teste.
